# %% [markdown]
# <a href="https://colab.research.google.com/github/FabioASC/DNC-Case/blob/main/SVM_Breast_cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import metrics, datasets

# %%
bc = datasets.load_breast_cancer()
x = bc.data
y = bc.target

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=1, stratify=y)

# %%
plt.scatter(x[:,0], x[:,1], c=y)

# %%
sc = StandardScaler()
sc.fit(x_train)
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)

# %%
svc = SVC(C =1, random_state=1, kernel='linear')
svc.fit(x_train_std, y_train)
# Out:
# SVC(C=1, kernel='linear', random_state=1)

# %%
y_predict = svc.predict(x_test_std)

# %%
print("Acurácia:", metrics.accuracy_score(y_test, y_predict))
# Out:
# Acurácia: 0.9532163742690059
